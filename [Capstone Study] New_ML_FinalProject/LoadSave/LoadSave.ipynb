# %%
# %cd '/content/drive/My Drive/Colab Notebooks/CS114.K21.KHTN/[Capstone Study] New_ML_FinalProject'
# Out:
# /content/drive/My Drive/Colab Notebooks/CS114.K21.KHTN/[Capstone Study] New_ML_FinalProject

# %%
import os
import numpy as np
from Preprocessing.processor import preprocessing
from FetureExtraction.ExtractFeature import *
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-f858b0ee1125> in <module>()
#       1 import os
#       2 import numpy as np
# ----> 3 from Preprocessing.processor import preprocessing
#       4 from FetureExtraction.ExtractFeature import *
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in get_data(self, path)
#
# OSError: [Errno 5] Input/output error

# %%
def Load_image(namefile):
    dirPath = '/content/drive/My Drive/Colab Notebooks/Capstone_Dataset' + namefile
    images = []
    class_name = ['B','C','D','E','CT']
    labels = []
    for id,class_ in enumerate(class_name):
        fname = os.path.join(dirPath,class_)
        for filename in os.listdir(fname):
            if filename.endswith('.jpg') or filename.endswith('.JPG'): 
                imagePath = os.path.join(fname,filename)
                img = cv2.imread(imagePath)
                img = preprocessing(img)
                images.append(img)
                labels.append(id)
    return (np.array(images), np.array(labels))
